# %% [markdown]
# # BinaryTraceHeader
#
# ``` python
# BinaryTraceHeader(
#     values=(lambda: {k: 0 for k in TH_FIELDS})(),
#     keys_loaded=list(),
# )
# ```
#
# Container for parsed binary trace header values.
