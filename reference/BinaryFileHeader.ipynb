# %% [markdown]
# #
#
# # BinaryFileHeader
#
# ``` python
# BinaryFileHeader(
#     values=(lambda: {k: 0 for k in FH_FIELDS})(),
#     keys_loaded=(lambda: list(FH_FIELDS))(),
# )
# ```
#
# Container for parsed binary file header values.
